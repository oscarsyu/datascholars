# %%
from datascience import *
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## Good visualization fundamentals:
#
# https://www.darkhorseanalytics.com/portfolio/2016/1/7/data-looks-better-naked-pie-charts
# https://www.darkhorseanalytics.com/portfolio/w24s5qofnzm4wqmsdfq98kwx035tew
# https://www.darkhorseanalytics.com/portfolio/data-looks-better-naked-bar-charts

# %%
plt.style.use("ggplot")

# %%
# plt.style.use("fivethirtyeight")

# %%
child_mortality = Table.read_table("child_mortality.csv")
countries = Table.read_table("countries.csv")
poverty = Table.read_table("poverty.csv")

# %%
child_mortality.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>geo</th> <th>time</th> <th>child_mortality_0_5_year_olds_dying_per_1000_born</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>afg </td> <td>1800</td> <td>468.6                                            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>afg </td> <td>1801</td> <td>468.6                                            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>afg </td> <td>1802</td> <td>468.6                                            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>afg </td> <td>1803</td> <td>468.6                                            </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>afg </td> <td>1804</td> <td>468.6                                            </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (40751 rows omitted)</p>

# %%
countries.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>country</th> <th>gwid</th> <th>name</th> <th>world_6region</th> <th>income_groups</th> <th>landlocked</th> <th>g77_and_oecd_countries</th> <th>main_religion_2008</th> <th>gapminder_list</th> <th>alternative_1</th> <th>alternative_2</th> <th>alternative_3</th> <th>alternative_4_cdiac</th> <th>pandg</th> <th>god_id</th> <th>alt_5</th> <th>upper_case_name</th> <th>code</th> <th>number</th> <th>arb1</th> <th>arb2</th> <th>arb3</th> <th>arb4</th> <th>arb5</th> <th>arb6</th> <th>is--country</th> <th>world_4region</th> <th>latitude</th> <th>longitude</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>abkh     </td> <td>i0  </td> <td>Abkhazia             </td> <td>europe_central_asia     </td> <td>nan                </td> <td>nan       </td> <td>others                </td> <td>nan               </td> <td>Abkhazia             </td> <td>nan                            </td> <td>nan          </td> <td>nan          </td> <td>nan                </td> <td>nan        </td> <td>GE-AB            </td> <td>nan  </td> <td>nan            </td> <td>nan </td> <td>nan   </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>True       </td> <td>europe       </td> <td>nan     </td> <td>nan      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>afg      </td> <td>i1  </td> <td>Afghanistan          </td> <td>south_asia              </td> <td>low_income         </td> <td>landlocked</td> <td>g77                   </td> <td>muslim            </td> <td>Afghanistan          </td> <td>Islamic Republic of Afghanistan</td> <td>nan          </td> <td>nan          </td> <td>Afghanistan        </td> <td>AFGHANISTAN</td> <td>AF               </td> <td>nan  </td> <td>AFGHANISTAN    </td> <td>AFG </td> <td>4     </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>True       </td> <td>asia         </td> <td>33      </td> <td>66       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>akr_a_dhe</td> <td>i2  </td> <td>Akrotiri and Dhekelia</td> <td>europe_central_asia     </td> <td>nan                </td> <td>coastline </td> <td>others                </td> <td>nan               </td> <td>Akrotiri and Dhekelia</td> <td>nan                            </td> <td>nan          </td> <td>nan          </td> <td>nan                </td> <td>nan        </td> <td>Akrotiri_Dhekelia</td> <td>nan  </td> <td>nan            </td> <td>nan </td> <td>nan   </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>True       </td> <td>europe       </td> <td>nan     </td> <td>nan      </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>alb      </td> <td>i3  </td> <td>Albania              </td> <td>europe_central_asia     </td> <td>upper_middle_income</td> <td>coastline </td> <td>others                </td> <td>muslim            </td> <td>Albania              </td> <td>nan                            </td> <td>nan          </td> <td>nan          </td> <td>Albania            </td> <td>ALBANIA    </td> <td>AL               </td> <td>nan  </td> <td>ALBANIA        </td> <td>ALB </td> <td>8     </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>True       </td> <td>europe       </td> <td>41      </td> <td>20       </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>dza      </td> <td>i4  </td> <td>Algeria              </td> <td>middle_east_north_africa</td> <td>upper_middle_income</td> <td>coastline </td> <td>g77                   </td> <td>muslim            </td> <td>Algeria              </td> <td>nan                            </td> <td>nan          </td> <td>nan          </td> <td>Algeria            </td> <td>ALGERIA    </td> <td>DZ               </td> <td>nan  </td> <td>ALGERIA        </td> <td>DZA </td> <td>12    </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>nan </td> <td>True       </td> <td>africa       </td> <td>28      </td> <td>3        </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (270 rows omitted)</p>

# %%
poverty.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>geo</th> <th>time</th> <th>extreme_poverty_percent_people_below_125_a_day</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>alb </td> <td>1996</td> <td>0.2                                           </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>alb </td> <td>2002</td> <td>0.73                                          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>alb </td> <td>2004</td> <td>0.53                                          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>alb </td> <td>2005</td> <td>0.44                                          </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>alb </td> <td>2008</td> <td>0.2                                           </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (1094 rows omitted)</p>

# %%
selected_countries = countries.select(0, 2, 3, 4)
selected_countries.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>country</th> <th>name</th> <th>world_6region</th> <th>income_groups</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>abkh     </td> <td>Abkhazia             </td> <td>europe_central_asia     </td> <td>nan                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>afg      </td> <td>Afghanistan          </td> <td>south_asia              </td> <td>low_income         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>akr_a_dhe</td> <td>Akrotiri and Dhekelia</td> <td>europe_central_asia     </td> <td>nan                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>alb      </td> <td>Albania              </td> <td>europe_central_asia     </td> <td>upper_middle_income</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>dza      </td> <td>Algeria              </td> <td>middle_east_north_africa</td> <td>upper_middle_income</td>
#         </tr>
#     </tbody>
# </table>
# <p>... (270 rows omitted)</p>

# %%
all_joined = child_mortality.join("geo", selected_countries, "country")

# %%
all_joined.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>geo</th> <th>time</th> <th>child_mortality_0_5_year_olds_dying_per_1000_born</th> <th>name</th> <th>world_6region</th> <th>income_groups</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>abw </td> <td>1980</td> <td>26.34                                            </td> <td>Aruba</td> <td>america      </td> <td>high_income  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>abw </td> <td>1981</td> <td>25.4                                             </td> <td>Aruba</td> <td>america      </td> <td>high_income  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>abw </td> <td>1982</td> <td>24.6                                             </td> <td>Aruba</td> <td>america      </td> <td>high_income  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>abw </td> <td>1983</td> <td>23.96                                            </td> <td>Aruba</td> <td>america      </td> <td>high_income  </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>abw </td> <td>1984</td> <td>23.48                                            </td> <td>Aruba</td> <td>america      </td> <td>high_income  </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (40751 rows omitted)</p>

# %%
data_2014 = all_joined.where("time", are.equal_to(2014))

# %%
data_2014.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>geo</th> <th>time</th> <th>child_mortality_0_5_year_olds_dying_per_1000_born</th> <th>name</th> <th>world_6region</th> <th>income_groups</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>abw </td> <td>2014</td> <td>16.8                                             </td> <td>Aruba      </td> <td>america            </td> <td>high_income        </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>afg </td> <td>2014</td> <td>93.9                                             </td> <td>Afghanistan</td> <td>south_asia         </td> <td>low_income         </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>ago </td> <td>2014</td> <td>162.2                                            </td> <td>Angola     </td> <td>sub_saharan_africa </td> <td>upper_middle_income</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>alb </td> <td>2014</td> <td>14.4                                             </td> <td>Albania    </td> <td>europe_central_asia</td> <td>upper_middle_income</td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>and </td> <td>2014</td> <td>2.9                                              </td> <td>Andorra    </td> <td>europe_central_asia</td> <td>high_income        </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (206 rows omitted)</p>

# %%
#Histogram
plt.hist(data_2014.column(2));

# %%
#add titles, legend, axes
plt.hist(data_2014.column(2), label="mortatlity rate");
plt.title("Distribution of child mortality rates");
plt.xlabel("moratality rate per unit");
plt.legend();

# %%
sns.distplot(data_2014.column(2), label="mortality rate")
plt.title("Distribution of child mortality rates");
plt.xlabel("mortality rate per unit")
plt.legend()

# %%
by_region = data_2014.group("world_6region", sum)

# %%
by_region = by_region.drop("time sum").drop("geo sum").drop("name sum").drop("income_groups sum")

# %%
by_region.show(5)
# Out:
# <table border="1" class="dataframe">
#     <thead>
#         <tr>
#             <th>world_6region</th> <th>child_mortality_0_5_year_olds_dying_per_1000_born sum</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>america                 </td> <td>728.72                                               </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>east_asia_pacific       </td> <td>853.55                                               </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>europe_central_asia     </td> <td>489.9                                                </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>middle_east_north_africa</td> <td>439.82                                               </td>
#         </tr>
#     </tbody>
#         <tr>
#             <td>south_asia              </td> <td>356.5                                                </td>
#         </tr>
#     </tbody>
# </table>
# <p>... (1 rows omitted)</p>

# %%
plt.figure(figsize=(15, 10))
plt.bar(x = "world_6region", height = "child_mortality_0_5_year_olds_dying_per_1000_born sum", data = by_region)
plt.title("Mortality by Region");
plt.xlabel("Region");

# %%
#line chart with time

# %%
#dont worry about this
child_mortality = pd.read_csv("child_mortality.csv")
countries = pd.read_csv("countries.csv")
poverty = pd.read_csv("poverty.csv")

# %%
countries_selected = countries.iloc[:, [0, 2, 3, 4]]

# %%
countries_selected.head(5)
# Out:
#      country                   name             world_6region  \
# 0       abkh               Abkhazia       europe_central_asia
# 1        afg            Afghanistan                south_asia
# 2  akr_a_dhe  Akrotiri and Dhekelia       europe_central_asia
# 3        alb                Albania       europe_central_asia
# 4        dza                Algeria  middle_east_north_africa
#
#          income_groups
# 0                  NaN
# 1           low_income
# 2                  NaN
# 3  upper_middle_income
# 4  upper_middle_income

# %%
all_joined = child_mortality.merge(countries_selected, how="left", right_on="country", left_on = "geo")

# %%
all_joined.head(5)
# Out:
#    geo  time  child_mortality_0_5_year_olds_dying_per_1000_born country  \
# 0  afg  1800                                              468.6     afg
# 1  afg  1801                                              468.6     afg
# 2  afg  1802                                              468.6     afg
# 3  afg  1803                                              468.6     afg
# 4  afg  1804                                              468.6     afg
#
#           name world_6region income_groups
# 0  Afghanistan    south_asia    low_income
# 1  Afghanistan    south_asia    low_income
# 2  Afghanistan    south_asia    low_income
# 3  Afghanistan    south_asia    low_income
# 4  Afghanistan    south_asia    low_income

# %%
with_poverty = all_joined.merge(poverty, how="left", left_on = ["geo", "time"], right_on = ["geo", "time"])

# %%
with_poverty.head(5)
# Out:
#    geo  time  child_mortality_0_5_year_olds_dying_per_1000_born country  \
# 0  afg  1800                                              468.6     afg
# 1  afg  1801                                              468.6     afg
# 2  afg  1802                                              468.6     afg
# 3  afg  1803                                              468.6     afg
# 4  afg  1804                                              468.6     afg
#
#           name world_6region income_groups  \
# 0  Afghanistan    south_asia    low_income
# 1  Afghanistan    south_asia    low_income
# 2  Afghanistan    south_asia    low_income
# 3  Afghanistan    south_asia    low_income
# 4  Afghanistan    south_asia    low_income
#
#    extreme_poverty_percent_people_below_125_a_day
# 0                                             NaN
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN

# %%
with_data = with_poverty[with_poverty.iloc[:, 7].isnull() == False]

# %%
with_data = with_data.rename(columns = {'child_mortality_0_5_year_olds_dying_per_1000_born': "mortality", "extreme_poverty_percent_people_below_125_a_day": "poverty_rate"})

# %%
with_data.head(5)
# Out:
#      geo  time  mortality country     name        world_6region  \
# 412  alb  1996       31.8     alb  Albania  europe_central_asia
# 418  alb  2002       23.6     alb  Albania  europe_central_asia
# 420  alb  2004       21.5     alb  Albania  europe_central_asia
# 421  alb  2005       20.5     alb  Albania  europe_central_asia
# 424  alb  2008       17.9     alb  Albania  europe_central_asia
#
#            income_groups  poverty_rate
# 412  upper_middle_income          0.20
# 418  upper_middle_income          0.73
# 420  upper_middle_income          0.53
# 421  upper_middle_income          0.44
# 424  upper_middle_income          0.20

# %% [markdown]
# https://seaborn.pydata.org/generated/seaborn.pairplot.html

# %%
sns.pairplot(with_data)

# %%
just_a_few = with_data[with_data["time"] == 2000][["mortality","income_groups"]]

# %%
just_a_few.head(5)
# Out:
#       mortality        income_groups
# 874       216.7  upper_middle_income
# 1306       20.2  upper_middle_income
# 1990        5.5          high_income
# 2854       88.0           low_income
# 3286       14.4  upper_middle_income

# %%
few_high = just_a_few[just_a_few["income_groups"] == 'high_income']["mortality"]
few_low = just_a_few[just_a_few["income_groups"] == 'low_income']["mortality"]
few_lmid = just_a_few[just_a_few["income_groups"] == 'lower_middle_income']["mortality"]
few_umid = just_a_few[just_a_few["income_groups"] == 'upper_middle_income']["mortality"]

# %%
few_high.head(5)
# Out:
# 1990     5.5
# 3502     5.8
# 6526     6.2
# 7426    10.9
# 9219     8.3
# Name: mortality, dtype: float64

# %%
plt.figure(figsize=(15, 9))
sns.distplot(few_high, label="high_income")
sns.distplot(few_low, label="low_income")
sns.distplot(few_lmid, label="lower middle income")
sns.distplot(few_umid, label="upper middle income")
plt.legend()

# %%
select_3 = with_data[["mortality", "poverty_rate", "income_groups"]]

# %%
select_3.head(5)
# Out:
#      mortality  poverty_rate        income_groups
# 412       31.8          0.20  upper_middle_income
# 418       23.6          0.73  upper_middle_income
# 420       21.5          0.53  upper_middle_income
# 421       20.5          0.44  upper_middle_income
# 424       17.9          0.20  upper_middle_income

# %%
sns.lmplot(x = "mortality", y="poverty_rate", hue="income_groups", data = select_3, height= 10)
plt.title("poverty_rate vs mortality_rate")
# Out:
# Text(0.5,1,'poverty_rate vs mortality_rate')

# %%
sns.jointplot(x = "mortality", y="poverty_rate", kind="reg", data = select_3, height= 10)

# %%
sns.residplot(x = "mortality", y="poverty_rate", data = select_3)

# %%
plt.figure(figsize=(16, 4));
sns.boxplot(x = "income_groups", y="poverty_rate", data = select_3)

# %%
plt.figure(figsize=(16, 4));
sns.violinplot(x = "income_groups", y="poverty_rate", data = select_3);

# %%
sns.violinplot(x = "income_groups", y="poverty_rate", data = select_3[select_3["income_groups"] == "upper_middle_income"]);

# %%
sns.violinplot(x = "income_groups", y="poverty_rate", data = select_3[select_3["income_groups"] == "lower_middle_income"]);

# %%
sns.violinplot(x = "income_groups", y="poverty_rate", data = select_3[select_3["income_groups"] == "high_income"]);

# %%
sns.violinplot(x = "income_groups", y="poverty_rate", data = select_3[select_3["income_groups"] == "low_income"]);
plt.title("Low Income")
# Out:
# Text(0.5,1,'Low Income')

# %%
us_data = with_data[with_data["name"] == "United States"]

# %%
us_data.head(5)
# Out:
#        geo  time  mortality country           name world_6region  \
# 38458  usa  1986       12.4     usa  United States       america
# 38463  usa  1991       10.9     usa  United States       america
# 38466  usa  1994        9.8     usa  United States       america
# 38469  usa  1997        8.9     usa  United States       america
# 38472  usa  2000        8.4     usa  United States       america
#
#       income_groups  poverty_rate
# 38458   high_income          0.68
# 38463   high_income          0.67
# 38466   high_income          0.67
# 38469   high_income          1.00
# 38472   high_income          0.67

# %%
plt.title("Nice n Gucci skrrt skrrt yeet")
sns.lineplot(x= "time", y="mortality", data = us_data);

# %%
#us plot of poverty
plt.title("We're f**ked")
sns.lineplot(x= "time", y="poverty_rate", data = us_data);

# %% [markdown]
# https://seaborn.pydata.org/examples/index.html
#
# https://python-graph-gallery.com

# %% [markdown]
# # Personal Note:
# # Thank you all for an amazing semester
#
# Love you guys and I'm grateful for the opportunity to teach you all.  I wish you guys the very best!  I had a blast and I hope you did as well.  Please feel free to contact me at `oscar.syu@berkeley.edu` about anything.
#
#
#
# Say hi to me if you guys see me!!
