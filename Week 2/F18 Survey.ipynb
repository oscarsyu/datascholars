# %%
#import statements
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.style.use("ggplot")

# %%
responses = pd.read_csv("responses.csv").drop(np.array(["Timestamp", "Your name", "Email Address",
                                          "Your preferred name (if different from your name)", 
                                          "Your pronouns", 
                                          "Do you have anything else you would like me to know about you or what you would like from me?"]),
                                axis = 1)

# %%
responses.columns = ["Reason Joining Scholars", "Hopes", "Focus", 
                     "Preference: Concept Review", "Preference: Practice Problems",
                     "Preference: Work time",
                     "Preference: Guest Speakers", "Preference: Industry", "Other activities"
                    ]

# %%
responses["Other activities"] = responses["Other activities"].fillna("")

# %%
responses
# Out:
#                               Reason Joining Scholars  \
# 0   To learn more about opportunities related in t...
# 1   Extra practice and gain a deeper understanding...
# 2   To develop a better understanding of Data Scie...
# 3        To learn and prepare myself for data science
# 4   I wanted to be in a inclusive community that w...
# 5   I want to learn more about the data science in...
# 6   I wanted to sign up for the Data Scholars Prog...
# 7   To learn more about Data Science and to increa...
# 8   I don't have much experience with cs or data s...
# 9   Because I'm interested in follow a career rela...
# 10  I am an intended Data Science major and I want...
# 11                                                YES
# 12  To join a community for engagement and also le...
# 13  Engaging with a community of like-minded peers...
# 14  To be in a community of people with an interes...
# 15  As a way to learn more about Data Science itse...
# 16  One of my friends was part of this program and...
# 17  To gain a deeper understanding of the Data 8 m...
# 18         I wanted to learn more about Data Science.
# 19  I am new to CS and Data Science, and I would l...
# 20  I signed up for the Data Scholars Program beca...
# 21  I'd like to meet other minorities as well as w...
# 22  I want to get a fuller experience in the Data ...
# 23  I had no coding experience and resource to lea...
#
#                                                 Hopes  \
# 0          To build connections and do well in data 8
# 1   I hope to improve both in data science but als...
# 2   A solid foundation of Data Science that will a...
# 3   Learning material even beyond the actual lectu...
# 4   I hope to solidify what I learn in the Data 8 ...
# 5   I hope to solidify the concepts I learn in the...
# 6   I hope to learn more about data science as a f...
# 7   I hope to do more practice problems and have a...
# 8   I hope to have greater command and preparation...
# 9       Get more involved with the Data Science world
# 10  I hope to get help with Data 8 and well as lea...
# 11  I want to learn more about Data Science, Visua...
# 12  I hope to be more connected and motivated abou...
# 13  A better understanding of Data Science and new...
# 14  I hope to understand data science at a deeper,...
# 15  I hope to learn a lot more about data science ...
# 16  I hope to be able to understand the depths and...
# 17  I hope to learn more about data science as a f...
# 18  I want to get more familiar with the data scie...
# 19  Success in Data 8, a conceptual understanding ...
# 20  I hope to have a better understanding of Pytho...
# 21     Learn from and connect with keynote speakers.
# 22  I hope to get a better sense of the data scien...
# 23  I want to learn Python deeply and know how to ...
#
#                                                 Focus  \
# 0   Listening to guest speakers talk about their w...
# 1           Getting extra help/preparation for Data 8
# 2   Listening to guest speakers talk about their w...
# 3   Listening to guest speakers talk about their w...
# 4   Getting extra help/preparation for Data 8, Lea...
# 5           Getting extra help/preparation for Data 8
# 6   Getting extra help/preparation for Data 8, Lea...
# 7           Getting extra help/preparation for Data 8
# 8   Listening to guest speakers talk about their w...
# 9   Getting extra help/preparation for Data 8, Lea...
# 10  Listening to guest speakers talk about their w...
# 11  Listening to guest speakers talk about their w...
# 12  Listening to guest speakers talk about their w...
# 13  Getting extra help/preparation for Data 8, Hop...
# 14  Listening to guest speakers talk about their w...
# 15  Listening to guest speakers talk about their w...
# 16  Getting extra help/preparation for Data 8, Lea...
# 17          Getting extra help/preparation for Data 8
# 18  Listening to guest speakers talk about their w...
# 19  Getting extra help/preparation for Data 8, Lea...
# 20  Getting extra help/preparation for Data 8, Per...
# 21  Listening to guest speakers talk about their w...
# 22  Listening to guest speakers talk about their w...
# 23  Listening to guest speakers talk about their w...
#
#     Preference: Concept Review  Preference: Practice Problems  \
# 0                            1                              2
# 1                            4                              5
# 2                            1                              2
# 3                            5                              1
# 4                            1                              2
# 5                            3                              1
# 6                            1                              3
# 7                            4                              5
# 8                            1                              3
# 9                            1                              2
# 10                           1                              5
# 11                           5                              3
# 12                           4                              5
# 13                           5                              1
# 14                           2                              3
# 15                           3                              4
# 16                           2                              1
# 17                           1                              2
# 18                           5                              4
# 19                           1                              2
# 20                           1                              3
# 21                           1                              4
# 22                           5                              1
# 23                           1                              3
#
#     Preference: Work time  Preference: Guest Speakers  Preference: Industry  \
# 0                       3                           4                     5
# 1                       1                           2                     3
# 2                       4                           3                     5
# 3                       4                           3                     2
# 4                       3                           5                     4
# 5                       2                           4                     5
# 6                       4                           5                     2
# 7                       3                           2                     1
# 8                       5                           2                     4
# 9                       5                           4                     3
# 10                      4                           3                     2
# 11                      4                           2                     1
# 12                      3                           2                     1
# 13                      4                           3                     2
# 14                      4                           1                     5
# 15                      5                           1                     2
# 16                      3                           5                     4
# 17                      3                           5                     4
# 18                      3                           1                     2
# 19                      3                           5                     4
# 20                      2                           4                     5
# 21                      3                           5                     2
# 22                      4                           2                     3
# 23                      2                           4                     5
#
#                                      Other activities
# 0
# 1
# 2
# 3
# 4
# 5                                                  No
# 6   Resume workshops, preparing for summer interns...
# 7
# 8
# 9   get information related to research in Data Sc...
# 10
# 11  Go to company trip, Data science companies (su...
# 12
# 13                                         Not really
# 14
# 15              No, I think you've captured it great!
# 16
# 17  Maybe introduction to data science-related org...
# 18
# 19                                                N/a
# 20
# 21  Help making resumes/prepare for job interviews...
# 22        Resume workshops or research opportunities.
# 23

# %%
responses.describe()
# Out:
#        Preference: Concept Review  Preference: Practice Problems  \
# count                   24.000000                      24.000000
# mean                     2.458333                       2.791667
# std                      1.693444                       1.382473
# min                      1.000000                       1.000000
# 25%                      1.000000                       2.000000
# 50%                      1.500000                       3.000000
# 75%                      4.000000                       4.000000
# max                      5.000000                       5.000000
#
#        Preference: Work time  Preference: Guest Speakers  Preference: Industry
# count              24.000000                   24.000000             24.000000
# mean                3.375000                    3.208333              3.166667
# std                 1.013496                    1.413573              1.434563
# min                 1.000000                    1.000000              1.000000
# 25%                 3.000000                    2.000000              2.000000
# 50%                 3.000000                    3.000000              3.000000
# 75%                 4.000000                    4.250000              4.250000
# max                 5.000000                    5.000000              5.000000

# %%
concept_review = responses["Preference: Concept Review"]
work_time = responses["Preference: Work time"]
guests = responses["Preference: Guest Speakers"]
tools = responses["Preference: Industry"]
plt.figure(figsize = (15, 10))
ax1 = plt.subplot(221)
ax2 = plt.subplot(222)
ax3 = plt.subplot(223)
ax4 = plt.subplot(224)

sns.distplot(concept_review,ax = ax1);
sns.distplot(work_time,ax = ax2);
sns.distplot(guests,ax = ax3);
sns.distplot(tools,ax = ax4);

# %%
concept_count = responses.groupby("Preference: Concept Review").count()
work_count = responses.groupby("Preference: Work time").count()
guests_count = responses.groupby("Preference: Guest Speakers").count()
tools_count = responses.groupby("Preference: Industry").count()
plt.figure(figsize = (15, 10))
ax1 = plt.subplot(221)
ax2 = plt.subplot(222)
ax3 = plt.subplot(223)
ax4 = plt.subplot(224)

sns.barplot(x = concept_count.index, y = concept_count["Hopes"], ax = ax1);
sns.barplot(work_count.index, y = work_count["Hopes"], ax = ax2);
sns.barplot(guests_count.index, y = guests_count["Hopes"], ax = ax3);
sns.barplot(tools_count.index, y = tools_count["Hopes"], ax = ax4);

# %%
from sklearn.preprocessing import MultiLabelBinarizer
encoder = MultiLabelBinarizer()

# %%
by_cat = responses["Focus"].str.split(",")
by_cat = by_cat.apply(lambda x: [i.strip() for i in x])
encoded = encoder.fit_transform(by_cat)
list(encoder.classes_)
focus_table = pd.DataFrame(columns =list(encoder.classes_), data = encoded)
focus_table.columns = ["Extra Help", "Research", "Community", "Outside Topics", "Guests", "Personal Projects"]
focus_totals = focus_table.sum()

plt.figure(figsize = (15, 5))
sns.barplot(x = focus_totals.index, y = focus_totals);

# %%
# from nltk.stem.snowball import SnowballStemmer
# stemmer = SnowballStemmer("english")
# stemmer.stem("having")
# for i in text_columns:
#     text_columns[i] = text_columns[i].apply(lambda x: [stemmer.stem(j) for j in x])

# %%
from nltk.tokenize import word_tokenize

# %%
s = "This is a simple sentence"
tokens = word_tokenize(s)

# %%
text_columns = responses[["Reason Joining Scholars", "Hopes", "Other activities"]]
# for i in text_columns:
#     text_columns[i] = text_columns[i].apply(word_tokenize)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tvec_reasons = TfidfVectorizer(min_df=0.0, max_df=7, stop_words='english', ngram_range= (1, 3))

tvec_reasons_weights = tvec_reasons.fit_transform(text_columns["Reason Joining Scholars"].str.lower())

reasons_weights = np.asarray(tvec_reasons_weights.mean(axis=0)).ravel().tolist()
reasons_weights_df = pd.DataFrame({'term': tvec_reasons.get_feature_names(), 'weight': reasons_weights})
reasons_weights_sorted = reasons_weights_df.sort_values(by = 'weight', ascending = False)

# %%
reasons_weights_sorted.head(20)
# Out:
#                      term    weight
# 227            learn data  0.048787
# 228    learn data science  0.048787
# 454                   yes  0.041667
# 434                wanted  0.040285
# 417         understanding  0.034522
# 104            experience  0.030624
# 122                 field  0.029840
# 45              community  0.028857
# 163                  help  0.025795
# 428                  want  0.025663
# 34                  class  0.025197
# 114                 extra  0.024689
# 418    understanding data  0.024586
# 239                  like  0.023711
# 320               program  0.023629
# 342          related data  0.023195
# 341               related  0.023195
# 343  related data science  0.023195
# 439          wanted learn  0.023124
# 440     wanted learn data  0.023124

# %%
tvec_hopes = TfidfVectorizer(min_df=0.0, max_df=5, stop_words='english', ngram_range= (1, 2))

tvec_hopes_weights = tvec_hopes.fit_transform(text_columns["Hopes"].str.lower())

hopes_weights = np.asarray(tvec_hopes_weights.mean(axis=0)).ravel().tolist()
hopes_weights_df = pd.DataFrame({'term': tvec_hopes.get_feature_names(), 'weight': hopes_weights})
hopes_weights_sorted = hopes_weights_df.sort_values(by = 'weight', ascending = False)

hopes_weights_sorted.head(20)

#adjust weights
# Out:
#                      term    weight
# 245         science field  0.046387
# 89                  field  0.046387
# 292         understanding  0.042929
# 304                  want  0.034449
# 15                 better  0.033118
# 126            hope learn  0.030454
# 314                 world  0.029766
# 17   better understanding  0.029678
# 294    understanding data  0.027500
# 196                   new  0.026433
# 165              learning  0.026055
# 190              material  0.025805
# 20                  build  0.024577
# 270              speakers  0.022949
# 9                   apply  0.022417
# 288            understand  0.022312
# 273               subject  0.021753
# 67                 deeper  0.021753
# 25                  class  0.021476
# 59             data class  0.021476

# %%
tvec_other = TfidfVectorizer(min_df=0.0, max_df=100.0, stop_words='english', ngram_range= (1, 2))

tvec_other_weights = tvec_other.fit_transform(text_columns["Other activities"].str.lower())

other_weights = np.asarray(tvec_other_weights.mean(axis=0)).ravel().tolist()
other_weights_df = pd.DataFrame({'term': tvec_other.get_feature_names(), 'weight': other_weights})
other_weights_sorted = other_weights_df.sort_values(by = 'weight', ascending = False)

other_weights_sorted.head(20)

#adjust weights
# Out:
#                       term    weight
# 44                  really  0.041667
# 55                 science  0.028503
# 11                    data  0.028503
# 12            data science  0.028503
# 35           opportunities  0.025361
# 48                research  0.025361
# 68               workshops  0.024969
# 52        resume workshops  0.024969
# 51                  resume  0.024969
# 33                   maybe  0.019813
# 2                   campus  0.019699
# 45                 related  0.019699
# 43                projects  0.019308
# 50  research opportunities  0.017131
# 70      workshops research  0.017131
# 61                   think  0.015749
# 67             ve captured  0.015749
# 6           captured great  0.015749
# 16                   great  0.015749
# 62                think ve  0.015749

# %%
def words_in_texts(words, texts):
    indicator_array = 1 * np.array([texts.str.contains(i) for i in words]).T
    
    return indicator_array

# %%
#ngrams changed so that word length is 1, does not exactly correspond to above weights
other_top10 = other_weights_sorted.iloc[0:11]["term"]
other_top10_features = other_top10
other_top10_df = pd.DataFrame()
other_top10_df["features"] = other_top10_features
other_top10_counts = np.count_nonzero(words_in_texts(other_top10, text_columns["Other activities"]), axis = 0)
other_top10_df["counts"] = other_top10_counts
other_top10_df = other_top10_df.sort_values(by = "counts")
plt.figure(figsize = (15, 5))
sns.barplot(x = other_top10_df["features"], y = other_top10_df["counts"]);

# %%
#ngrams changed so that word length is 1, does not exactly correspond to above weights
reasons_top10 = reasons_weights_sorted.iloc[0:11]["term"]
reasons_top10_features = reasons_top10
reasons_top10_df = pd.DataFrame()
reasons_top10_df["features"] = reasons_top10_features
reasons_top10_counts = np.count_nonzero(words_in_texts(reasons_top10, text_columns["Reason Joining Scholars"]), axis = 0)
reasons_top10_df["counts"] = reasons_top10_counts
reasons_top10_df = reasons_top10_df.sort_values(by = "counts")
plt.figure(figsize = (15, 5))
sns.barplot(x = reasons_top10_df["features"], y = reasons_top10_df["counts"]);

# %%
#ngrams changed so that word length is 1, does not exactly correspond to above weights
hopes_top10 = hopes_weights_sorted.iloc[0:11]["term"]
hopes_top10_features = hopes_top10
hopes_top10_df = pd.DataFrame()
hopes_top10_df["features"] = hopes_top10_features
hopes_top10_counts = np.count_nonzero(words_in_texts(hopes_top10, text_columns["Hopes"]), axis = 0)
hopes_top10_df["counts"] = hopes_top10_counts
hopes_top10_df = hopes_top10_df.sort_values(by = "counts")
plt.figure(figsize = (15, 5))
sns.barplot(x = hopes_top10_df["features"], y = hopes_top10_df["counts"]);
