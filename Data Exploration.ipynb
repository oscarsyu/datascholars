# %%
import numpy as np
from datascience import *
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
nba = Table.read_table("historical_projections.csv")

# %%
nba

# %%
baches = pd.read_csv("bachelorette.csv")

# %%
baches = baches[1:]

# %%
baches["CONTESTANT"] = baches["CONTESTANT"].str.replace(r"\d+_","")

# %%
baches

# %%
baches = Table.read_table("bachelorette.csv")

# %%
baches

# %%
baches = baches.take(np.arange(1, baches.num_rows))

# %%
baches

# %%
np.array(baches.row(0))

# %%
winners = baches.where("ELIMINATION-10", "W")

# %%
winners

# %%
first_impression = winners.where("ELIMINATION-1", "R1")

# %%
winners.show(15)

# %%
winners.group("ELIMINATION-1").barh("ELIMINATION-1")

# %%
bachelorettes.where("ELIMINATION-10", "W").group("ELIMINATION-1")

# %%
3/8

# %% [markdown]
# ## Observed test statistic:
# 0.375 of winners on the Bachelorette received first impression roses

# %% [markdown]
# Null: It is not more likely to win the bachelorette if you receive a first impression rose, winning is due to random chance
# Alternative: It is better to win the first impression rose.  Winning is not due to chance.

# %%
first_impr_rose = winners.group("ELIMINATION-1")

# %%
first_impr_rose = first_impr_rose.with_column("First Impression", make_array("Got a Rose", "Didn't")).drop(0)

# %%
sns.barplot(first_impr_rose.column(1), first_impr_rose.column(0));
plt.title("Winners who received and didn't receive first impression roses");

# %%
bachelorettes = baches.where("SHOW", "Bachelorette")
bachelor = baches.where("SHOW", "Bachelor")

# %%
bachelorettes.group("SEASON")

# %%
dudes_with_nice_jawlines = np.arange(0, 25)

# %%
result = make_array()
for i in np.arange(2000):
    over_seasons = make_array()
    
    for j in np.arange(0, 13): #what happens if i incre
        rand = np.random.choice(dudes_with_nice_jawlines)
        first_imp = rand == 1
        over_seasons = np.append(over_seasons, first_imp)
    prop_winners = np.count_nonzero(over_seasons)/13
    result = np.append(result, prop_winners)

# %%
result

# %%
tbl = Table().with_column("null", result)

# %%
tbl.hist()

# %%
np.count_nonzero(result >= 0.375)

# %%
13*0.375

# %% [markdown]
# # Ideas:
# - difference in number of dates it takes for bachelors and bachelorettes?
# - any trends over the seasons?
# - any differences between seasons?
# - differences in number of dates/ how many people were on each date?

# %%
from sas7bdat import SAS7BDAT

# %%
with SAS7BDAT("nsch_2011_2012_puf.sas7bdat") as file:
    df_sas = file.to_data_frame()

# %%
df_sas
# Out:
#         IDNUMR  SAMPLE  STATE  MSA_STAT  TOTKIDS4  AGEYR_CHILD  FLG_18_MNTH  \
# 0      94595.0     1.0   25.0       1.0       2.0          8.0          0.0
# 1      14134.0     1.0   30.0       2.0       1.0         14.0          0.0
# 2      74020.0     1.0    5.0       1.0       1.0          3.0          0.0
# 3      48557.0     1.0   42.0       NaN       2.0         13.0          0.0
# 4      79075.0     1.0    2.0       1.0       1.0          2.0          0.0
# 5      31113.0     1.0   36.0       1.0       2.0         10.0          0.0
# 6      84981.0     1.0    4.0       1.0       3.0          4.0          0.0
# 7      70534.0     1.0   19.0       1.0       1.0         16.0          0.0
# 8      45873.0     1.0    1.0       NaN       1.0         17.0          0.0
# 9      44069.0     1.0   43.0       1.0       2.0         10.0          0.0
# 10     16272.0     1.0   49.0       1.0       2.0         17.0          0.0
# ...

# %%
def load_sas(sasfile,
             encoding="utf8",
             encoding_errors="replace"):

    with SAS7BDAT(sasfile, encoding=encoding,encoding_errors=encoding_errors) as sas:
        sas = iter(sas)
#         columns = [c for c in next(sas)]
        
        df = pd.DataFrame(data = sas)
#                           columns=columns)
        return df

# %%
load_sas("nsch_2011_2012_puf.sas7bdat")
